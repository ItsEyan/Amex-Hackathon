# %%
import pandas as pd

# %%
data = pd.read_csv('65d4f0fcb8af9_amex_campus_challenge_train_3.csv', index_col=0)

# %%
output = pd.read_csv('65d4b84c5b826_sample_rows_for_submission.csv', index_col=0)

# %%
#data.fillna(data.mean())

# %%
len(data["customer"].unique())
# Out:
# 462584

# %%
len(data["merchant"].unique())
# Out:
# 591973

# %%
filtered = data[data['merchant_profile_01'].isna()]

# %%
filtered['merchant'].unique().size
# Out:
# 69164

# %%
data.head(20)
# Out:
#                  activation  customer_digital_activity_04  customer_spend_01  \
# ind_recommended
# 0                         0                           NaN         107.215862
# 0                         0                           NaN          35.552000
# 0                         0                           NaN          31.623103
# 0                         0                           NaN         112.277391
# 1                         0                           NaN         448.427273
# 0                         0                           NaN          81.858000
# 0                         0                           NaN                NaN
# 0                         0                           NaN          45.241765
# 0                         0                           NaN          18.223538
# 0                         0                           NaN        1400.000000
# 0                         0                           NaN         196.890000
# ...

# %%
output.head(5)
# Out:
#           merchant  predicted_score
# customer
# 140              8         0.518033
# 140            120         0.038266
# 140            301         0.308177
# 140            352         0.194978
# 140            692         0.155000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12229978 entries, 0 to 0
# Data columns (total 70 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   activation                    int64
#  1   customer_digital_activity_04  float64
#  2   customer_spend_01             float64
#  3   customer_industry_spend_01    float64
#  4   customer_industry_spend_02    float64
#  5   customer_industry_spend_03    float64
#  6   customer_industry_spend_04    float64
#  7   customer_industry_spend_05    float64
#  8   customer_spend_02             float64
#  9   customer_spend_03             float64
#  10  customer_merchant_02          float64
#  11  customer_merchant_01          float64
#  12  customer_spend_04             float64
#  13  customer_spend_05             float64
#  14  customer_spend_06             float64
#  15  customer_spend_07             float64
#  16  merchant_spend_01             float64
# ...

# %%
columns = [col for col in data.columns if col.startswith('merchant')]
sub_df = data[columns]

# %%
sub_df.head(5)
# Out:
#                  merchant_spend_01  merchant_spend_02  merchant_spend_03  \
# ind_recommended
# 0                        29.781042               43.0                0.0
# 0                        34.643313               97.0                0.0
# 0                      1731.000000                2.0             1731.0
# 0                        54.800000                4.0                0.0
# 1                       166.000000                1.0                0.0
#
#                  merchant_spend_04  merchant_spend_05  merchant_spend_06  \
# ind_recommended
# 0                              0.0                0.0               32.0
# 0                              0.0                0.0               15.0
# 0                              2.0                2.0                8.0
# 0                              0.0                0.0               62.0
# 1                              0.0                0.0               74.0
#
# ...

# %%
data['merchant'].unique
# Out:
# <bound method Series.unique of ind_recommended
# 0    152285
# 0     39032
# 0      7439
# 0    485069
# 1    536004
#       ...
# 0    564879
# 0    453544
# 0    259023
# 0    305617
# 0    557003
# Name: merchant, Length: 12229978, dtype: int64>
